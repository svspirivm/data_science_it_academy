# %% [markdown]
# ### Проанализировать датафрейм статистики NBA. (файл nba.csv)

# %% [markdown]
# Вывести:
# 1. Проранжировать бюджет команд на зарплату от самого высокого до самого низкого.
# 2. 10 наиболее высокооплачиваемых игроков в лиге.
# 3. 3 наиболее высооплачиваемых игроков в каждой команде.
# 4. Предложить первые пятерки каждой команды на основе их зарплаты (учитывайте,
#    что в первой пятерке на каждой позиции один игрок (см. рисунок)).
# 5. Самая молодая и самая возростная команда в лиге.
# 6. Наиболее часто используемый номер игрока в лиге.
# 7. Имя и рост самого высокого и самого низкого игрока в лиге в метрической системе.
#
# P.S. Возможные пропуски в зарплатной ведомости заполнить медианным значением зарплаты команды игрока с пропуском.

# %% [markdown]
# **Import of libraries and settings**

# %%
import pandas as pd
import numpy as np
import copy
import warnings
warnings.simplefilter('ignore')

# %%
data_nba_statistics = pd.read_csv('nba.csv', delimiter=',')
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 20)
data_nba_statistics                                         #read data, set options and show part of the dataframe
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]

# %% [markdown]
# **Preparation of data**

# %%
data_nba_statistics.drop(data_nba_statistics.tail(1).index, inplace = True) #last row is empty so we can delete it
data_nba_statistics
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 452           Kentucky  2239800.0
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
#
# [457 rows x 9 columns]

# %%
data_nba_statistics['Salary'].isnull().sum()                 #the amount of empty values in column "Salary"
# Out:
# 11

# %%
data_nba_statistics.groupby('Team')['Salary'].median() #median salary in each team
# Out:
# Team
# Atlanta Hawks         2854940.0
# Boston Celtics        3021242.5
# Brooklyn Nets         1335480.0
# Charlotte Hornets     4204200.0
# Chicago Bulls         2380440.0
#                         ...
# Sacramento Kings      3156600.0
# San Antonio Spurs     2814000.0
# Toronto Raptors       2900000.0
# Utah Jazz             2433333.0
# Washington Wizards    4000000.0
# Name: Salary, Length: 30, dtype: float64

# %%
data_nba_statistics['Team'].isnull().sum()                  #check empty values in column 'Team'
# Out:
# 0

# %%
data_nba_statistics['Salary'] = data_nba_statistics.groupby('Team')['Salary'].transform(lambda x: x.fillna(x.median()))
data_nba_statistics                                         #fill empty fields in column "Salary"
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University  3021242.5
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 452           Kentucky  2239800.0
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
#
# [457 rows x 9 columns]

# %%
data_nba_statistics['Salary'].isnull().sum()                  #check if all voids has been filled
# Out:
# 0

# %%
#convert height and weight to the International System of Units (kilos, meters)
data_nba_statistics['Height'] = data_nba_statistics['Height'].apply(lambda x: round((30.48 * int(x.split('-')[0]) + 2.54 * int(x.split('-')[1])) / 100, 2))
data_nba_statistics['Weight'] *= 0.4536
data_nba_statistics
# Out:
#               Name            Team  Number Position   Age  Height    Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    1.88   81.6480
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    1.98  106.5960
# 2     John Holland  Boston Celtics    30.0       SG  27.0    1.96   92.9880
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    1.96   83.9160
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0    2.08  104.7816
# ..             ...             ...     ...      ...   ...     ...       ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0    2.08  106.1424
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    1.91   92.0808
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    1.85   81.1944
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    2.21  116.1216
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    2.13  104.7816
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University  3021242.5
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 452           Kentucky  2239800.0
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
#
# [457 rows x 9 columns]

# %% [markdown]
# **Task 1**
# 1. Проранжировать бюджет команд на зарплату от самого высокого до самого низкого.

# %%
#we just need to sort players by their salary in each team
data_nba_statistics.groupby(['Team','Name']).max().sort_values(by=['Team','Salary'], ascending=[True, False])
# Out:
#                                     Number Position   Age  Height    Weight  \
# Team               Name
# Atlanta Hawks      Paul Millsap        4.0       PF  31.0    2.03  111.5856
#                    Al Horford         15.0        C  30.0    2.08  111.1320
#                    Tiago Splitter     11.0        C  31.0    2.11  111.1320
#                    Jeff Teague         0.0       PG  27.0    1.88   84.3696
#                    Kyle Korver        26.0       SG  35.0    2.01   96.1632
# ...                                    ...      ...   ...     ...       ...
# Washington Wizards Kelly Oubre Jr.    12.0       SF  20.0    2.01   92.9880
#                    Garrett Temple     17.0       SG  30.0    1.98   88.4520
#                    Jarell Eddie        8.0       SG  24.0    2.01   98.8848
#                    JJ Hickson         21.0        C  27.0    2.06  109.7712
#                    Marcus Thornton    15.0       SF  29.0    1.93   92.9880
#
#                                                  College      Salary
# Team               Name
# Atlanta Hawks      Paul Millsap           Louisiana Tech  18671659.0
#                    Al Horford                    Florida  12000000.0
#                    Tiago Splitter                    NaN   9756250.0
#                    Jeff Teague               Wake Forest   8000000.0
#                    Kyle Korver                 Creighton   5746479.0
# ...                                                  ...         ...
# Washington Wizards Kelly Oubre Jr.                Kansas   1920240.0
#                    Garrett Temple                    LSU   1100602.0
#                    Jarell Eddie            Virginia Tech    561716.0
#                    JJ Hickson       North Carolina State    273038.0
#                    Marcus Thornton                   LSU    200600.0
#
# [457 rows x 7 columns]

# %% [markdown]
# **Task 2**
# 2. 10 наиболее высокооплачиваемых игроков в лиге.

# %%
data_nba_statistics.nlargest(10, ['Salary'])
# Out:
#                 Name                   Team  Number Position   Age  Height  \
# 109      Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    1.98
# 169     LeBron James    Cleveland Cavaliers    23.0       SF  31.0    2.03
# 33   Carmelo Anthony        New York Knicks     7.0       SF  32.0    2.03
# 251    Dwight Howard        Houston Rockets    12.0        C  30.0    2.11
# 339       Chris Bosh             Miami Heat     1.0       PF  32.0    2.11
# 100       Chris Paul   Los Angeles Clippers     3.0       PG  31.0    1.83
# 414     Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    2.06
# 164     Derrick Rose          Chicago Bulls     1.0       PG  27.0    1.91
# 349      Dwyane Wade             Miami Heat     3.0       SG  34.0    1.93
# 23       Brook Lopez          Brooklyn Nets    11.0        C  28.0    2.13
#
#        Weight       College      Salary
# 109   96.1632           NaN  25000000.0
# 169  113.4000           NaN  22970500.0
# 33   108.8640      Syracuse  22875000.0
# 251  120.2040           NaN  22359364.0
# 339  106.5960  Georgia Tech  22192730.0
# 100   79.3800   Wake Forest  21468695.0
# 414  108.8640         Texas  20158622.0
# 164   86.1840       Memphis  20093064.0
# 349   99.7920     Marquette  20000000.0
# 23   124.7400      Stanford  19689000.0

# %% [markdown]
# **Task 3**
# 3. 3 наиболее высооплачиваемых игроков в каждой команде.

# %%
richest_players = pd.DataFrame()                           #create new dataframe for players
tmp = copy.deepcopy(data_nba_statistics)                   #making deep copy of main dataframe to keep it undamaged
tmp.set_index('Team', inplace=True)                        #set field 'team' as index
for i in tmp.index.unique():                               #go through each team
    max_salary = tmp.loc[i].nlargest(3, ['Salary'])        #find three highest paid players in each team
    richest_players = pd.concat([richest_players, max_salary]) #add them to new dataframe
richest_players
# Out:
#                                     Name  Number Position   Age  Height  \
# Team
# Boston Celtics              Amir Johnson    90.0       PF  29.0    2.06
# Boston Celtics             Avery Bradley     0.0       PG  25.0    1.88
# Boston Celtics             Isaiah Thomas     4.0       PG  27.0    1.75
# Brooklyn Nets                Brook Lopez    11.0        C  28.0    2.13
# Brooklyn Nets             Thaddeus Young    30.0       PF  27.0    2.03
# ...                                  ...     ...      ...   ...     ...
# Portland Trail Blazers          Ed Davis    17.0        C  27.0    2.08
# Portland Trail Blazers  Gerald Henderson     9.0       SG  28.0    1.96
# Utah Jazz                 Gordon Hayward    20.0       SF  26.0    2.03
# Utah Jazz                 Derrick Favors    15.0       PF  24.0    2.08
# Utah Jazz                     Alec Burks    10.0       SG  24.0    1.98
#
#                           Weight         College      Salary
# Team
# Boston Celtics          108.8640             NaN  12000000.0
# Boston Celtics           81.6480           Texas   7730337.0
# Boston Celtics           83.9160      Washington   6912869.0
# Brooklyn Nets           124.7400        Stanford  19689000.0
# Brooklyn Nets           100.2456    Georgia Tech  11235955.0
# ...                          ...             ...         ...
# Portland Trail Blazers  108.8640  North Carolina   6980802.0
# Portland Trail Blazers   97.5240            Duke   6000000.0
# Utah Jazz               102.5136          Butler  15409570.0
# Utah Jazz               120.2040    Georgia Tech  12000000.0
# Utah Jazz                97.0704        Colorado   9463484.0
#
# [90 rows x 8 columns]

# %% [markdown]
# **Task 4**
# 4. Предложить первые пятерки каждой команды на основе их зарплаты (учитывайте,
#    что в первой пятерке на каждой позиции один игрок (см. рисунок)).

# %%
tmp = copy.deepcopy(data_nba_statistics)                   #making deep copy of main dataframe to keep it undamaged
tmp.set_index(['Team', 'Position'], inplace=True)          #now we'll have multiindex 'team' + 'position'

# %%
teams_from_richest_players = pd.DataFrame()                           #new dataframe for result
for i in tmp.index.unique():                                         #our new indexes - pairs: {data, team}
    max_salary_in_position = tmp.loc[i].nlargest(1, ['Salary'])      #then we just find best paid players in each category
    teams_from_richest_players = pd.concat([teams_from_richest_players, max_salary_in_position]) 
teams_from_richest_players.sort_values(by = ['Team', 'Position'], inplace = True)
teams_from_richest_players
# Out:
#                                         Name  Number   Age  Height    Weight  \
# Team               Position
# Atlanta Hawks      C              Al Horford    15.0  30.0    2.08  111.1320
#                    PF           Paul Millsap     4.0  31.0    2.03  111.5856
#                    PG            Jeff Teague     0.0  27.0    1.88   84.3696
#                    SF        Thabo Sefolosha    25.0  32.0    2.01   99.7920
#                    SG            Kyle Korver    26.0  35.0    2.01   96.1632
# ...                                      ...     ...   ...     ...       ...
# Washington Wizards C            Nene Hilario    42.0  33.0    2.11  113.4000
#                    PF        Markieff Morris     5.0  26.0    2.08  111.1320
#                    PG              John Wall     2.0  25.0    1.93   88.4520
#                    SF        Otto Porter Jr.    22.0  23.0    2.03   89.8128
#                    SG           Bradley Beal     3.0  22.0    1.96   93.8952
#
#                                     College      Salary
# Team               Position
# Atlanta Hawks      C                Florida  12000000.0
#                    PF        Louisiana Tech  18671659.0
#                    PG           Wake Forest   8000000.0
#                    SF                   NaN   4000000.0
#                    SG             Creighton   5746479.0
# ...                                     ...         ...
# Washington Wizards C                    NaN  13000000.0
#                    PF                Kansas   8000000.0
#                    PG              Kentucky  15851950.0
#                    SF            Georgetown   4662960.0
#                    SG               Florida   5694674.0
#
# [149 rows x 7 columns]

# %% [markdown]
# **Task 5**
# 5. Самая молодая и самая возрастная команда в лиге.

# %%
average_age = data_nba_statistics.groupby('Team')['Age'].mean() #calculate average age and then find min and max
average_age = round(average_age, 2)
print("The team with minimal average age of member is", average_age.idxmin(), 'with average age', average_age.min())
print("The team with maximal average age of member is", average_age.idxmax(), 'with average age', average_age.max())
# Out:
# The team with minimal average age of member is Utah Jazz with average age 24.47
# The team with maximal average age of member is San Antonio Spurs with average age 31.6

# %% [markdown]
# **Task 6**
# 6. Наиболее часто используемый номер игрока в лиге.

# %%
data_nba_statistics['Number'].mode()    #the most frequently used value in field "Number"
# Out:
# 0    5.0
# dtype: float64

# %% [markdown]
# **Task 7**
# 7. Имя и рост самого высокого и самого низкого игрока в лиге в метрической системе.

# %%
height_of_players = data_nba_statistics[['Name', 'Height']].sort_values(by = 'Height', ascending = False)
print("The tallest player is", height_of_players.iloc[0].Name, 'with height', height_of_players.iloc[0].Height, 'meters')
print("The shortest player is", height_of_players.iloc[-1].Name, 'with height', height_of_players.iloc[-1].Height, 'meters')
#here we just sorted players by their height so that the first player will be the tallest ant the last one will be the shortest
# Out:
# The tallest player is Kristaps Porzingis with height 2.21 meters
# The shortest player is Isaiah Thomas with height 1.75 meters
